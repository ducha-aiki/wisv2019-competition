# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import os
import csv
import seaborn as sns

# %%
INPUT_DATA_DIR = 'input_data/'
fnames = sorted([f for f in os.listdir(os.path.join(INPUT_DATA_DIR))  if f.endswith('csv') ])
patches_fnames = [os.path.join(INPUT_DATA_DIR, f) for f in fnames if 'patches' in f]
ori_fnames = [os.path.join(INPUT_DATA_DIR, f) for f  in fnames if 'ori' in f]

# %%
for f in patches_fnames:
    print (f)
# Out:
# input_data/DD1_big_patches.csv
# input_data/DD2_big_patches.csv
# input_data/DD3_big_patches.csv
# input_data/DD4_big_patches.csv
# input_data/DD5_big_patches.csv
# input_data/DD6_big_patches.csv
# input_data/bark1_big_patches.csv
# input_data/bark2_big_patches.csv
# input_data/bark3_big_patches.csv
# input_data/bark4_big_patches.csv
# input_data/bark5_big_patches.csv
# input_data/bark6_big_patches.csv
# input_data/boat1_big_patches.csv
# input_data/boat2_big_patches.csv
# input_data/boat3_big_patches.csv
# input_data/boat4_big_patches.csv
# input_data/boat5_big_patches.csv
# input_data/boat6_big_patches.csv
# input_data/build0_big_patches.csv
# input_data/build1_big_patches.csv
# input_data/cart0_big_patches.csv
# input_data/cart1_big_patches.csv
# input_data/castle0_big_patches.csv
# input_data/castle1_big_patches.csv
# input_data/castle2_big_patches.csv
# input_data/chatnoir1_big_patches.csv
# input_data/chatnoir2_big_patches.csv
# input_data/chatnoir3_big_patches.csv
# input_data/chatnoir4_big_patches.csv
# input_data/chatnoir5_big_patches.csv
# input_data/chatnoir6_big_patches.csv
# input_data/church0_big_patches.csv
# input_data/church1_big_patches.csv
# input_data/corridor0_big_patches.csv
# input_data/corridor1_big_patches.csv
# input_data/corridor2_big_patches.csv
# input_data/dante0_big_patches.csv
# input_data/dante1_big_patches.csv
# input_data/dc0_big_patches.csv
# input_data/dc1_big_patches.csv
# input_data/dc2_big_patches.csv
# input_data/desk0_big_patches.csv
# input_data/desk1_big_patches.csv
# input_data/desk2_big_patches.csv
# input_data/dtua0_big_patches.csv
# input_data/dtua1_big_patches.csv
# input_data/dtua2_big_patches.csv
# input_data/dtub0_big_patches.csv
# input_data/dtub1_big_patches.csv
# input_data/dtub2_big_patches.csv
# input_data/dtuc0_big_patches.csv
# input_data/dtuc1_big_patches.csv
# input_data/dtuc2_big_patches.csv
# input_data/dtud0_big_patches.csv
# input_data/dtud1_big_patches.csv
# input_data/dtud2_big_patches.csv
# input_data/dtuf0_big_patches.csv
# input_data/dtuf1_big_patches.csv
# input_data/dtuf2_big_patches.csv
# input_data/dtug0_big_patches.csv
# input_data/dtug1_big_patches.csv
# input_data/dtug2_big_patches.csv
# input_data/duckhunt1_big_patches.csv
# input_data/duckhunt2_big_patches.csv
# input_data/duckhunt3_big_patches.csv
# input_data/duckhunt4_big_patches.csv
# input_data/duckhunt5_big_patches.csv
# input_data/duckhunt6_big_patches.csv
# input_data/et0_big_patches.csv
# input_data/et1_big_patches.csv
# input_data/et2_big_patches.csv
# input_data/facade0_big_patches.csv
# input_data/facade1_big_patches.csv
# input_data/floor1_big_patches.csv
# input_data/floor2_big_patches.csv
# input_data/floor3_big_patches.csv
# input_data/floor4_big_patches.csv
# input_data/floor5_big_patches.csv
# input_data/floor6_big_patches.csv
# input_data/fountain0_big_patches.csv
# input_data/fountain1_big_patches.csv
# input_data/fountain2_big_patches.csv
# input_data/frame0_big_patches.csv
# input_data/frame1_big_patches.csv
# input_data/graf1_big_patches.csv
# input_data/graf2_big_patches.csv
# input_data/graf3_big_patches.csv
# input_data/graf4_big_patches.csv
# input_data/graf5_big_patches.csv
# input_data/graf6_big_patches.csv
# input_data/groupsac0_big_patches.csv
# input_data/groupsac1_big_patches.csv
# input_data/herzjesu0_big_patches.csv
# input_data/herzjesu1_big_patches.csv
# input_data/herzjesu2_big_patches.csv
# input_data/horse0_big_patches.csv
# input_data/horse1_big_patches.csv
# input_data/kermit0_big_patches.csv
# input_data/kermit1_big_patches.csv
# input_data/kermit2_big_patches.csv
# input_data/marilyn1_big_patches.csv
# input_data/marilyn2_big_patches.csv
# input_data/marilyn3_big_patches.csv
# input_data/marilyn4_big_patches.csv
# input_data/marilyn5_big_patches.csv
# input_data/marilyn6_big_patches.csv
# input_data/mario1_big_patches.csv
# input_data/mario2_big_patches.csv
# input_data/mario3_big_patches.csv
# input_data/mario4_big_patches.csv
# input_data/mario5_big_patches.csv
# input_data/mario6_big_patches.csv
# input_data/op1_big_patches.csv
# input_data/op2_big_patches.csv
# input_data/op3_big_patches.csv
# input_data/op4_big_patches.csv
# input_data/op5_big_patches.csv
# input_data/op6_big_patches.csv
# input_data/outside1_big_patches.csv
# input_data/outside2_big_patches.csv
# input_data/outside3_big_patches.csv
# input_data/outside4_big_patches.csv
# input_data/outside5_big_patches.csv
# input_data/outside6_big_patches.csv
# input_data/pen0_big_patches.csv
# input_data/pen1_big_patches.csv
# input_data/pen2_big_patches.csv
# input_data/plant0_big_patches.csv
# input_data/plant1_big_patches.csv
# input_data/posters1_big_patches.csv
# input_data/posters2_big_patches.csv
# input_data/posters3_big_patches.csv
# input_data/posters4_big_patches.csv
# input_data/posters5_big_patches.csv
# input_data/posters6_big_patches.csv
# input_data/rooster0_big_patches.csv
# input_data/rooster1_big_patches.csv
# input_data/scale0_big_patches.csv
# input_data/scale1_big_patches.csv
# input_data/screen1_big_patches.csv
# input_data/screen2_big_patches.csv
# input_data/screen3_big_patches.csv
# input_data/screen4_big_patches.csv
# input_data/screen5_big_patches.csv
# input_data/screen6_big_patches.csv
# input_data/shelf0_big_patches.csv
# input_data/shelf1_big_patches.csv
# input_data/shelf2_big_patches.csv
# input_data/spidey1_big_patches.csv
# input_data/spidey2_big_patches.csv
# input_data/spidey3_big_patches.csv
# input_data/spidey4_big_patches.csv
# input_data/spidey5_big_patches.csv
# input_data/spidey6_big_patches.csv
# input_data/sponge0_big_patches.csv
# input_data/sponge1_big_patches.csv
# input_data/sponge2_big_patches.csv
# input_data/standing0_big_patches.csv
# input_data/standing1_big_patches.csv
# input_data/statue0_big_patches.csv
# input_data/statue1_big_patches.csv
# input_data/teddy0_big_patches.csv
# input_data/teddy1_big_patches.csv
# input_data/teddy2_big_patches.csv
# input_data/tribal0_big_patches.csv
# input_data/tribal1_big_patches.csv
# input_data/tribal2_big_patches.csv
# input_data/valbonne0_big_patches.csv
# input_data/valbonne1_big_patches.csv
# input_data/valencia0_big_patches.csv
# input_data/valencia1_big_patches.csv
# input_data/wall1_big_patches.csv
# input_data/wall2_big_patches.csv
# input_data/wall3_big_patches.csv
# input_data/wall4_big_patches.csv
# input_data/wall5_big_patches.csv
# input_data/wall6_big_patches.csv
# input_data/webcam0_big_patches.csv
# input_data/webcam1_big_patches.csv

# %%
fname = patches_fnames[3]
patches = np.loadtxt(fname, delimiter=',')

# %%
h,w = patches.shape
PS = int(np.sqrt(w))
num_p = h

# %%
#i=0
i+=1
plt.imshow(255-patches[i,:].reshape(PS,PS))
